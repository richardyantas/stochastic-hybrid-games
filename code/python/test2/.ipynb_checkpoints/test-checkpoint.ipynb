# %%
a = [2,5,4]

type(a)

import numpy as np

b = np.linspace(0,5,5)

print(b)
# Out:
# [0.   1.25 2.5  3.75 5.  ]

# %%
import numpy as np
import matplotlib.pyplot as plt

t = np.linspace(0,200,200)
plt.plot(t)
plt.grid()
plt.show()

print( len(t) )
V = np.ones(200)
# for i in range(0,5): # i: 0,1,2,3,4


tau = 60
for i in range(0,len(V)-1):
    V[i+1] = V[i] + tau*(40-1*V[i]);

plt.plot(t, V ,label='V')
plt.grid()
plt.show()
# Out:
# 200
# 0
# (200, 200)
# 1
# (200, 200)
# 2
# (200, 200)
# 3
# (200, 200)
# 4
# (200, 200)
# /home/richard/.local/lib/python2.7/site-packages/ipykernel_launcher.py:19: RuntimeWarning: overflow encountered in double_scalars
# /home/richard/.local/lib/python2.7/site-packages/ipykernel_launcher.py:19: RuntimeWarning: invalid value encountered in double_scalars
# /usr/lib/python2.7/dist-packages/matplotlib/ticker.py:1914: RuntimeWarning: overflow encountered in multiply
#   steps = self._extended_steps * scale
