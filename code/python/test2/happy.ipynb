# %%
class Singleton(object):
    def __new__(cls):
        if not hasattr(cls, 'instance'):
            cls.instance = super(Singleton, cls).__new__(cls)
        return cls.instance

    
    
# s1 and s2 will refer to same object.
# ----------------------------------------
s1 = Singleton()
print("First object",  s1)

s2 = Singleton()
print("Second object",  s2)
# Out:
# ('First object', <__main__.Singleton object at 0x7f480c610b90>)
# ('Second object', <__main__.Singleton object at 0x7f480c610b90>)

# %%
#taup = 5*60
#Horizont = 2*24*60*60 
#nump = Horizont/taup


#tp = np.linspace(0,Horizont,nump)
#print(tp)

#Tep = np.interp(tp,t,Te)

#print(Horizont)
#print(len(t),len(Te), len(tp),len(Tep))

#plt.stem(Tep)
#plt.plot(t,Te)
#plt.plot(tp,Tep)
#plt.grid(True)
#plt.show()

#print("ddd")

import numpy as np
import matplotlib.pyplot as plt

t = np.linspace(0, 10, 11)
y = np.power(t,2)

plt.stem(t,y,use_line_collection = False) # step
plt.grid()
plt.show()

# %%
tt = np.linspace(0,10,num=3)

yy = np.interp(tt,t,y)

plt.stem(tt,yy)
plt.grid()
plt.show()

# %%
tau = 0.5
Horizont = 4
num = Horizont/tau

t = np.linspace(0,Horizont,num+1)
plt.stem(t)
plt.grid()
plt.show()

y = np.power(t,2)

plt.stem(t,y)
plt.grid()
plt.show()
# Out:
# /home/richard/.local/lib/python2.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: object of type <type 'float'> cannot be safely interpreted as an integer.
#   """

# %%
tau = 0.25/2
Horizont = 4
num = Horizont/tau

t_ = np.linspace(0,Horizont,num+1)

z = np.interp(t_,t,y)

plt.stem(t_,z)
plt.grid()
plt.show()
# Out:
# /home/richard/.local/lib/python2.7/site-packages/ipykernel_launcher.py:6: DeprecationWarning: object of type <type 'float'> cannot be safely interpreted as an integer.

# %%
import pandas as pd

dataRead = pd.read_csv("../SolarEnergy/Solargis_min15_Almeria_Spain.csv")


tau = 15*60           # Real time of the data 
Horizont = 24*60*60      # Real time Interval from  [0-Horizont]
num = Horizont/tau    # Num of intervals         [0 - num*tau]  , but there are num+1 points  t[0] - t[num]

t = np.linspace(0,Horizont,num+1)
T = dataRead['Temperature'].values.tolist()[0:num+1]

plt.stem(t,T)
plt.grid()
plt.show()

tau = 60
num = Horizont/tau

t_ = np.linspace(0,Horizont,num+1)
z = np.interp(t_,t,T)


plt.stem(t_,z)
plt.grid()
plt.show()

# %%
# with alt + ENTER we open an new console

# %%
a = 15*np.ones(5)
a
# Out:
# array([15., 15., 15., 15., 15.])

# %%
s = np.ones(4)
s

plt.stem(s)
# Out:
# <Container object of 3 artists>
